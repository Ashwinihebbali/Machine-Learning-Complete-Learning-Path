# %%
import pandas as pd
import matplotlib.pyplot as plt

#Load dataset
df = pd.read_csv("student_study_habits.csv")
print("Student Data (first 5 rows):")
print(df.head())

#Summary statistics
print("\nSummary Statistics:")

print(df.describe())

# Study Hours vs Exam Score
plt.scatter(df["study_hours"], df["exam_score"])
plt.xlabel("Study Hours")
plt.ylabel("Exam Score")
plt.title("Study Hours vs Exam Score")
plt.show()

# Attendance vs Exam Score
plt.scatter(df["attendance"], df["exam_score"], color="green")
plt.xlabel("Attendance (%)")
plt.ylabel("Exam Score")
plt.title("Attendance vs Exam Score")
plt.show()

# Participation vs Exam Score
plt.scatter(df["class_participation"], df["exam_score"], color="red")
plt.xlabel("Participation (0–10)")
plt.ylabel("Exam Score")
plt.title("Participation vs Exam Score")
plt.show()

#Correlation Matrix
print("\nCorrelation between factors and exam results:")
print(df.corr())
# Out:
# Student Data (first 5 rows):
#    study_hours  attendance  class_participation  exam_score
# 0         2.62        50.0                  3.2        50.4
# 1         1.56        80.0                  6.4        52.0
# 2         3.76        85.7                  3.0        97.7
# 3         3.55        93.5                  8.5       100.0
# 4         2.21        79.5                  4.5        70.9
#
# Summary Statistics:
#        study_hours  attendance  class_participation  exam_score
# count   120.000000  120.000000           120.000000  120.000000
# mean      2.853750   77.065000             5.066667   67.671667
# std       1.411906   11.444412             2.386881   25.318928
# min       0.200000   50.000000             0.000000   22.600000
# 25%       1.667500   70.800000             3.200000   45.475000
# 50%       2.775000   77.800000             5.050000   69.600000
# 75%       3.930000   85.825000             6.600000   85.000000
# ...
